# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Runtime results of 3 algorithms on 9 test cases
kmp_time = [12286908,12753839,13697136,11427283,14707967,15605780,11818982,11972233,12865538]
likmp_time = [10430083,8591294,11519903,21684747,26718007,31748295,9304418,9897024,10599525]
ikmp_time = [12687564,15498499,12862499,13007401,17245070,17088321,14228740,12743768,13629807]

# %%
X = [f"{x}.in" for x in range(1,10)]
barWidth = 0.25
r1 = np.arange(len(X))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]


plt.bar(r1, kmp_time, color='red', width=barWidth, edgecolor='white', label='KMP')
plt.bar(r2, likmp_time, color='green', width=barWidth, edgecolor='white', label='L-I-KMP')
plt.bar(r3, ikmp_time, color='blue', width=barWidth, edgecolor='white', label='I-KMP')
  
plt.xticks(X_axis, X)
plt.xlabel("File input")
plt.ylabel("Waktu dalam nanosecond")
plt.title("Perbandingan Runtime")
plt.legend()
plt.show()

# %%
# Character comparison incident counts of 3 algorithms on 9 test cases
kmp_comp = [1142363,1149708,1158903,1334934,1794223,2009504,1142401,1150425,1159149]
likmp_comp = [159489,111269,135720,596001,987521,998406,132543,144136,158615]
ikmp_comp = [1124821,1124369,1123683,1332932,1497346,1494865,1109217,1109027,1107925]

# %%
X = [f"{x}.in" for x in range(1,10)]
barWidth = 0.25
r1 = np.arange(len(X))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]


plt.bar(r1, kmp_comp, color='red', width=barWidth, edgecolor='white', label='KMP')
plt.bar(r2, likmp_comp, color='green', width=barWidth, edgecolor='white', label='L-I-KMP')
plt.bar(r3, ikmp_comp, color='blue', width=barWidth, edgecolor='white', label='I-KMP')
  
plt.xticks(X_axis, X)
plt.xlabel("File input")
plt.ylabel("Pencocokan karakter yang terjadi")
plt.title("Perbandingan Pencocokan Karakter")
plt.legend()
plt.show()
